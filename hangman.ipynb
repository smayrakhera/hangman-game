# %% [markdown]
# <a href="https://colab.research.google.com/github/smayrakhera/hangman-game/blob/main/hangman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Word list for the game
word_list = ['python', 'programming', 'openai', 'hangman', 'challenge', 'keyboard', 'laptop',"loop", "code", "java", "bash", "html", "byte", "list", "bool",
    "node", "data", "json", "git", "api", "bug", "machine", "coding", "network"]

# Pick a random word
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

# Game variables
display = ['_'] * word_length
lives = 6
guessed_letters = []

print("🎮 Welcome to Hangman!")
print("Guess the word, one letter at a time.")

# Hangman stages (empty first, builds up as lives decrease)
stages = [
    '''
      +---+
      |   |
          |
          |
          |
          |
    =========
    ''',
    '''
      +---+
      |   |
      O   |
          |
          |
          |
    =========
    ''',
    '''
      +---+
      |   |
      O   |
      |   |
          |
          |
    =========
    ''',
    '''
      +---+
      |   |
      O   |
     /|   |
          |
          |
    =========
    ''',
    '''
      +---+
      |   |
      O   |
     /|\\  |
          |
          |
    =========
    ''',
    '''
      +---+
      |   |
      O   |
     /|\\  |
     /    |
          |
    =========
    ''',
    '''
      +---+
      |   |
      O   |
     /|\\  |
     / \\  |
          |
    =========
    '''
]

# Game loop
while lives > 0 and '_' in display:
    print('\n' + ' '.join(display))
    guess = input("Guess a letter: ").lower()

    if guess in guessed_letters:
        print(f"⚠️ You already guessed '{guess}'. Try another letter.")
        continue

    guessed_letters.append(guess)

    if guess in chosen_word:
        for i in range(word_length):
            if chosen_word[i] == guess:
                display[i] = guess
        print("✅ Good guess!")
    else:
        print(f"❌ Wrong! You lose a life. ({lives - 1} left)")
        print(stages[6 - lives])
        lives -= 1

# Final hangman stage
print(stages[6 - lives])
print('\n' + ' '.join(display))

# Game over message
if '_' not in display:
    print(f"\n🎉 Congratulations! You guessed the word: {chosen_word}")
else:
    print(f"\n💀 Game Over! The word was: {chosen_word}")
# Out:
# 🎮 Welcome to Hangman!
# Guess the word, one letter at a time.
#
# _ _ _ _
# Guess a letter: d
# ✅ Good guess!
#
# d _ _ _
# Guess a letter: a
# ✅ Good guess!
#
# d a _ a
# Guess a letter: t
# ✅ Good guess!
#
#       +---+
#       |   |
#           |
#           |
#           |
#           |
# ...
#
#
# d a t a
#
# 🎉 Congratulations! You guessed the word: data
